# %% [markdown]
# ## A TALE OF TWO COVID PERIODS

# %%
#Import the necessary libraries
from pyecharts.charts import Map,Geo,Page
from pyecharts import options as opts 
from pyecharts.globals import ThemeType
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#Read the data into Python's memory
covid_data1=pd.read_csv('owid-covid-data.csv')

# %%
#Convert the date column to date format expressly
covid_data1['date']=pd.to_datetime(covid_data1['date'])

# %%
#Check the first few rows of the data 
covid_data1.head()
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba 2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba 2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba 2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba 2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba 2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
# 3       35973.781              NaN                    NaN
# 4       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.62             NaN           NaN                     NaN
# 1                11.62             NaN           NaN                     NaN
# 2                11.62             NaN           NaN                     NaN
# 3                11.62             NaN           NaN                     NaN
# 4                11.62             NaN           NaN                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         NaN            76.29                      NaN
# 1                         NaN            76.29                      NaN
# 2                         NaN            76.29                      NaN
# 3                         NaN            76.29                      NaN
# 4                         NaN            76.29                      NaN
#
# [5 rows x 41 columns]

# %%
#Filter out rows in which the total cases are missing
df=covid_data1[covid_data1['total_cases']!='']

# %%
df.head()
# Out:
#   iso_code      continent location       date  total_cases  new_cases  \
# 0      ABW  North America    Aruba 2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba 2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba 2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba 2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba 2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           NaN         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
# 3       35973.781              NaN                    NaN
# 4       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.62             NaN           NaN                     NaN
# 1                11.62             NaN           NaN                     NaN
# 2                11.62             NaN           NaN                     NaN
# 3                11.62             NaN           NaN                     NaN
# 4                11.62             NaN           NaN                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         NaN            76.29                      NaN
# 1                         NaN            76.29                      NaN
# 2                         NaN            76.29                      NaN
# 3                         NaN            76.29                      NaN
# 4                         NaN            76.29                      NaN
#
# [5 rows x 41 columns]

# %%
#Sort the data by date
df=covid_data1.sort_values(by=['date'],ascending=False)

# %%
#Get the data for the the date we are interested in
df_for_map=df[df['date']=='2020-06-01']

# %%
#Reset the index
df_for_map.reset_index(drop=True,inplace=True)

# %%
#Check the first few rows of the data needed for our work
df_for_map.head()
# Out:
#   iso_code      continent     location       date  total_cases  new_cases  \
# 0      JOR           Asia       Jordan 2020-06-01        739.0        5.0
# 1      UZB           Asia   Uzbekistan 2020-06-01       3662.0      108.0
# 2      SVK         Europe     Slovakia 2020-06-01       1522.0        1.0
# 3      LCA  North America  Saint Lucia 2020-06-01         18.0        0.0
# 4      AGO         Africa       Angola 2020-06-01         86.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0               4.429           9.0         0.0                0.000  ...
# 1              71.143          15.0         1.0                0.286  ...
# 2               1.857          28.0         0.0                0.000  ...
# 3               0.000           NaN         0.0                0.000  ...
# 4               2.429           4.0         0.0                0.000  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        8337.490              0.1                208.257
# 1        6253.104              NaN                724.417
# 2       30155.152              0.7                287.959
# 3       12951.839              NaN                204.620
# 4        5819.495              NaN                276.045
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.75             NaN           NaN                     NaN
# 1                 7.57             1.3          24.7                     NaN
# 2                 7.29            23.1          37.7                     NaN
# 3                11.62             NaN           NaN                  87.202
# 4                 3.94             NaN           NaN                  26.664
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                        1.40            74.53                    0.735
# 1                        4.00            71.72                    0.710
# 2                        5.82            77.54                    0.855
# 3                        1.30            76.20                    0.747
# 4                         NaN            61.15                    0.581
#
# [5 rows x 41 columns]

# %%
#Create two data series required for data visualization
country=(df_for_map['location'])
totalcases=list(df_for_map['total_cases'])

# %%
#prepare the data for visualization
list1=[[country[i],totalcases[i]] for i in range (len(country))]

# %%
#Create the map and set the size of the map
map1=Map(init_opts=opts.InitOpts(width="1000px",height="460px",theme=ThemeType.ROMANTIC))
# Out:
# C:\Users\MY PC\New folder\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)

# %%
#Add world map
map1.add("Total confirmed cases", list1,maptype="world",is_map_symbol_show=False);

# %%
# Set global configuration
#Change the legend from a sliding bar to the color bins by tweaking the VisualMapOpts parameter
#Add title and subtitle to the chart
map1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,
                                                       is_piecewise=True,
                                                       pieces=[{
                                                           "min": 500000
                                                       }, {
                                                           "min": 100000,"max":199999
                                                       },{"min":50000,"max":99999},{"min":10000,"max":49999},{"max":9999},]),
                     legend_opts=opts.LegendOpts(is_show=False),title_opts=opts.TitleOpts(title="Covid-19 Worldwide Total Cases",subtitle='Cases as at 1st June 2020',pos_left='center',padding=0,item_gap=2,title_textstyle_opts=opts.TextStyleOpts(color='darkblue',font_weight='bold',font_family='Courier New',font_size=30),subtitle_textstyle_opts=opts.TextStyleOpts
                                                                                         (color='green',font_weight='bold',font_family='Courier New',font_size=15)));

# %%
#Remove country name serving as label
map1.set_series_opts(label_opts=opts.LabelOpts(is_show=False));

# %%
#save the map as an html file
#map1.render('covid-worldwide-total-cases-1st-JUNE.html')
#Render the map inside the notebook
map1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic'
#         }
#     });
# </script>
#
#         <div id="c970344784d14a12b48512d74b69feb8" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world', 'romantic'], function(echarts) {
#                 var chart_c970344784d14a12b48512d74b69feb8 = echarts.init(
#                     document.getElementById('c970344784d14a12b48512d74b69feb8'), 'romantic', {renderer: 'canvas'});
#                 var option_c970344784d14a12b48512d74b69feb8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "Total confirmed cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jordan",
#                     "value": 739.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 3662.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 1522.0
#                 },
#                 {
#                     "name": "Saint Lucia",
#                     "value": 18.0
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 86.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 2045.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 1154.0
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 125.0
#                 },
#                 {
#                     "name": "Trinidad and Tobago",
#                     "value": 117.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 24.0
#                 },
#                 {
#                     "name": "Gibraltar",
#                     "value": 169.0
#                 },
#                 {
#                     "name": "Puerto Rico",
#                     "value": 3776.0
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 1172.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 1056.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 1675.0
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 442.0
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 3771.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 90936.0
#                 },
#                 {
#                     "name": "Latvia",
#                     "value": 1066.0
#                 },
#                 {
#                     "name": "Croatia",
#                     "value": 2246.0
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 32683.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 239638.0
#                 },
#                 {
#                     "name": "Haiti",
#                     "value": 2124.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 8070.0
#                 },
#                 {
#                     "name": "Syria",
#                     "value": 122.0
#                 },
#                 {
#                     "name": "Tajikistan",
#                     "value": 3807.0
#                 },
#                 {
#                     "name": "Georgia",
#                     "value": 783.0
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 483.0
#                 },
#                 {
#                     "name": "Bhutan",
#                     "value": 43.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 23786.0
#                 },
#                 {
#                     "name": "Cayman Islands",
#                     "value": 141.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 994.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": 336.0
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 38.0
#                 },
#                 {
#                     "name": "Sint Maarten (Dutch part)",
#                     "value": 77.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 324.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 7819.0
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 1011.0
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 778.0
#                 },
#                 {
#                     "name": "Kosovo",
#                     "value": 1083.0
#                 },
#                 {
#                     "name": "Hungary",
#                     "value": 3876.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 24.0
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 3081.0
#                 },
#                 {
#                     "name": "Guernsey",
#                     "value": 252.0
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 38655.0
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 26473.0
#                 },
#                 {
#                     "name": "Curacao",
#                     "value": 19.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 83.0
#                 },
#                 {
#                     "name": "Saint Kitts and Nevis",
#                     "value": 15.0
#                 },
#                 {
#                     "name": "Turks and Caicos Islands",
#                     "value": 12.0
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 56910.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 46442.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 24985.0
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 58964.0
#                 },
#                 {
#                     "name": "French Polynesia",
#                     "value": 60.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 30779.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 1137.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 84147.0
#                 },
#                 {
#                     "

# %%
#Read the data into memory
covid_data2=pd.read_csv('owid-covid-data-update-to-DEC.csv')

# %%
#Convert the date column to date format expressly
covid_data1['date']=pd.to_datetime(covid_data1['date'])

# %%
#Filter out rows in which the total cases are missing
df2=covid_data2[covid_data2['total_cases']!='']

# %%
#Sort the data by date
df2=covid_data2.sort_values(by=['date'],ascending=False)

# %%
#Get the data for the the date we are interested in
df_for_map2=df2[df2['date']=='2020-12-21']

# %%
#Reset the index
df_for_map2.reset_index(drop=True,inplace=True)

# %%
#Check the first few rows of the data needed for our work
df_for_map2.head()
# Out:
#   iso_code      continent       location        date  total_cases  new_cases  \
# 0      ZWE         Africa       Zimbabwe  2020-12-21      12422.0       97.0
# 1      CHN           Asia          China  2020-12-21      95150.0      100.0
# 2      NIC  North America      Nicaragua  2020-12-21       5938.0        0.0
# 3      NZL        Oceania    New Zealand  2020-12-21       2121.0        0.0
# 4      USA  North America  United States  2020-12-21   18035209.0   190519.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0             152.000         322.0         2.0                1.857  ...
# 1             103.286        4765.0         1.0                1.571  ...
# 2               7.286         163.0         0.0                0.143  ...
# 3               3.571          25.0         0.0                0.000  ...
# 4          215428.857      319364.0      1696.0             2655.286  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1899.775             21.4                307.846
# 1       15308.712              0.7                261.899
# 2        5321.444              3.2                137.016
# 3       36085.843              NaN                128.797
# 4       54225.446              1.2                151.089
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 1.82             1.6          30.7                  36.791
# 1                 9.74             1.9          48.4                     NaN
# 2                11.47             NaN           NaN                     NaN
# 3                 8.08            14.8          17.2                     NaN
# 4                10.79            19.1          24.6                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                        1.70            61.49                    0.535
# 1                        4.34            76.91                    0.752
# 2                        0.90            74.48                    0.658
# 3                        2.61            82.29                    0.917
# 4                        2.77            78.86                    0.924
#
# [5 rows x 52 columns]

# %%
#Create two data series required for data visualization
country2=(df_for_map2['location'])
totalcases2=list(df_for_map2['total_cases'])

# %%
#prepare the data for visualization
list2=[[country2[i],totalcases2[i]] for i in range (len(country2))]

# %%
#Create the map and set the size of the map
map2=Map(init_opts=opts.InitOpts(width="1000px",height="460px",theme=ThemeType.VINTAGE));
# Out:
# C:\Users\MY PC\New folder\lib\site-packages\pyecharts\charts\chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)

# %%
#Add world map
map2.add("Total confirmed cases", list2,maptype="world",is_map_symbol_show=False);

# %%
# Set global configuration
#Change the legend from a sliding bar to the color bins by tweaking the VisualMapOpts parameter
#Add title and subtitle to the chart
map2.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,
                                                       is_piecewise=True,
                                                       pieces=[{
                                                           "min": 500000
                                                       }, {
                                                           "min": 100000,"max":199999
                                                       },{"min":50000,"max":99999},{"min":10000,"max":49999},{"max":9999},]),
                     legend_opts=opts.LegendOpts(is_show=False),title_opts=opts.TitleOpts(title="Covid-19 Worldwide Total Cases",subtitle='Cases as at 21st December 2020',pos_left='center',padding=0,item_gap=2,title_textstyle_opts=opts.TextStyleOpts(color='darkblue',font_weight='bold',font_family='Courier New',font_size=30),subtitle_textstyle_opts=opts.TextStyleOpts
                                                                                         (color='green',font_weight='bold',font_family='Courier New',font_size=15)));

# %%
#Remove country name serving as label
map2.set_series_opts(label_opts=opts.LabelOpts(is_show=False));

# %%
#save the map as an html file
#map2.render('covid-worldwide-total-cases-21st-DEC.html')
#Render the map inside the notebook
map2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="ed77a0651d504f23b168930376dc8cf9" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world', 'vintage'], function(echarts) {
#                 var chart_ed77a0651d504f23b168930376dc8cf9 = echarts.init(
#                     document.getElementById('ed77a0651d504f23b168930376dc8cf9'), 'vintage', {renderer: 'canvas'});
#                 var option_ed77a0651d504f23b168930376dc8cf9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "Total confirmed cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Zimbabwe",
#                     "value": 12422.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 95150.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 5938.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 2121.0
#                 },
#                 {
#                     "name": "United States",
#                     "value": 18035209.0
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 1902.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 711540.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 254514.0
#                 },
#                 {
#                     "name": "Yemen",
#                     "value": 2087.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 587993.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 19299.0
#                 },
#                 {
#                     "name": "Myanmar",
#                     "value": 116982.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 17695.0
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 3436.0
#                 },
#                 {
#                     "name": "Uruguay",
#                     "value": 13477.0
#                 },
#                 {
#                     "name": "Guyana",
#                     "value": 6171.0
#                 },
#                 {
#                     "name": "Brunei",
#                     "value": 152.0
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 418002.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 44284.0
#                 },
#                 {
#                     "name": "Andorra",
#                     "value": 7602.0
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 1518067.0
#                 },
#                 {
#                     "name": "Mongolia",
#                     "value": 1006.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 666.0
#                 },
#                 {
#                     "name": "Haiti",
#                     "value": 9763.0
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 120348.0
#                 },
#                 {
#                     "name": "Monaco",
#                     "value": 742.0
#                 },
#                 {
#                     "name": "Moldova",
#                     "value": 135910.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 6200.0
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 1325915.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 524.0
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 4936.0
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 2724.0
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 78790.0
#                 },
#                 {
#                     "name": "Fiji",
#                     "value": 46.0
#                 },
#                 {
#                     "name": "Romania",
#                     "value": 593783.0
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 142159.0
#                 },
#                 {
#                     "name": "Bulgaria",
#                     "value": 192472.0
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 376220.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 1207333.0
#                 },
#                 {
#                     "name": "Burkina Faso",
#                     "value": 5301.0
#                 },
#                 {
#                     "name": "Guatemala",
#                     "value": 132867.0
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 33414.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 461505.0
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 194652.0
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 997517.0
#                 },
#                 {
#                     "name": "Burundi",
#                     "value": 762.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 100612.0
#                 },
#                 {
#                     "name": "Papua New Guinea",
#                     "value": 761.0
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 363.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 214038.0
#                 },
#                 {
#                     "name": "Palestine",
#                     "value": 123945.0
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 2079678.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 25849.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 460672.0
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 13578.0
#                 },
#                 {
#                     "name": "Oman",
#                     "value": 127931.0
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 16686.0
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 44336.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 519325.0
#                 },
#                 {
#                     "name

# %%
#It is possible to display the two charts all at once using the page submodule of the Pyechart library
Page=Page()

# %%
#Bring the two charts together
Page.add(map1,map2)

# %%
#Save the otuput 
#Render the output in the notebook
Page.render('doubletotalcase.html')
Page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world', 'romantic':'https://assets.pyecharts.org/assets/themes/romantic', 'vintage':'https://assets.pyecharts.org/assets/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="c3c2351ffeb949b6b26dad5a5fa6033f" style="width:1000px; height:460px;"></div>
#         <div id="1d0f159917e94105a8bf9b43cf1873ab" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world', 'romantic', 'vintage'], function(echarts) {
#                 var chart_c3c2351ffeb949b6b26dad5a5fa6033f = echarts.init(
#                     document.getElementById('c3c2351ffeb949b6b26dad5a5fa6033f'), 'romantic', {renderer: 'canvas'});
#                 var option_c3c2351ffeb949b6b26dad5a5fa6033f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "map",
#             "name": "Total confirmed cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Jordan",
#                     "value": 739.0
#                 },
#                 {
#                     "name": "Uzbekistan",
#                     "value": 3662.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "value": 1522.0
#                 },
#                 {
#                     "name": "Saint Lucia",
#                     "value": 18.0
#                 },
#                 {
#                     "name": "Angola",
#                     "value": 86.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 2045.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 1154.0
#                 },
#                 {
#                     "name": "Cambodia",
#                     "value": 125.0
#                 },
#                 {
#                     "name": "Trinidad and Tobago",
#                     "value": 117.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 24.0
#                 },
#                 {
#                     "name": "Gibraltar",
#                     "value": 169.0
#                 },
#                 {
#                     "name": "Puerto Rico",
#                     "value": 3776.0
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 1172.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 1056.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 1675.0
#                 },
#                 {
#                     "name": "Togo",
#                     "value": 442.0
#                 },
#                 {
#                     "name": "Guinea",
#                     "value": 3771.0
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 90936.0
#                 },
#                 {
#                     "name": "Latvia",
#                     "value": 1066.0
#                 },
#                 {
#                     "name": "Croatia",
#                     "value": 2246.0
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 32683.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 239638.0
#                 },
#                 {
#                     "name": "Haiti",
#                     "value": 2124.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 8070.0
#                 },
#                 {
#                     "name": "Syria",
#                     "value": 122.0
#                 },
#                 {
#                     "name": "Tajikistan",
#                     "value": 3807.0
#                 },
#                 {
#                     "name": "Georgia",
#                     "value": 783.0
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 483.0
#                 },
#                 {
#                     "name": "Bhutan",
#                     "value": 43.0
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 23786.0
#                 },
#                 {
#                     "name": "Cayman Islands",
#                     "value": 141.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 994.0
#                 },
#                 {
#                     "name": "Isle of Man",
#                     "value": 336.0
#                 },
#                 {
#                     "name": "Botswana",
#                     "value": 38.0
#                 },
#                 {
#                     "name": "Sint Maarten (Dutch part)",
#                     "value": 77.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 324.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 7819.0
#                 },
#                 {
#                     "name": "Central African Republic",
#                     "value": 1011.0
#                 },
#                 {
#                     "name": "Chad",
#                     "value": 778.0
#                 },
#                 {
#                     "name": "Kosovo",
#                     "value": 1083.0
#                 },
#                 {
#                     "name": "Hungary",
#                     "value": 3876.0
#                 },
#                 {
#                     "name": "Timor",
#                     "value": 24.0
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 3081.0
#                 },
#                 {
#                     "name": "Guernsey",
#                     "value": 252.0
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 38655.0
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 26473.0
#                 },
#                 {
#                     "name": "Curacao",
#                     "value": 19.0
#                 },
#                 {
#                     "name": "Liechtenstein",
#                     "value": 83.0
#                 },
#                 {
#                     "name": "Saint Kitts and Nevis",
#                     "value": 15.0
#                 },
#                 {
#                     "name": "Turks and Caicos Islands",
#                     "value": 12.0
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 56910.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 46442.0
#                 },
#                 {
#                     "name": "Tanzania",
#                     "value": 509.0
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 24985.0
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 58964.0
#                 },
#                 {
#                     "name": "French Polynesia",
#                     "value": 60.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 30779.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 1137.0
